# %% [markdown]
# This notebook contains experiment where number of trees (n_estimators) is varying, everything else is fixed

# %%
import numpy as np 
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/spambase_augmented.csv')

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
print('df shape : ' , df.shape)
print('X shape : ' , X.shape)
print('y shape : ', y.shape)
results = {}
# Out:
# df shape :  (4600, 1186)
# X shape :  (4600, 1185)
# y shape :  (4600,)

# %% [markdown]
# n_estimator = 5

# %%
num_trees = 5
train_error = []
test_error = []
train_sizes = np.linspace(0.1, 0.9, 9)

for train_size in train_sizes:
    X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=train_size,random_state=42)
    clf = RandomForestClassifier(n_estimators=num_trees,random_state=42,n_jobs=-1)
    clf.fit(X_train,y_train)

    #train error
    y_train_pred = clf.predict(X_train)
    cur_training_err = 1 - accuracy_score(y_train, y_train_pred)

    # Compute test error
    y_test_pred = clf.predict(X_test)
    cur_test_error = 1 - accuracy_score(y_test, y_test_pred)

    train_error.append(cur_training_err)
    test_error.append(cur_test_error)

plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_error, label="Training Error", marker='o', linestyle='-')
plt.plot(train_sizes, test_error, label="Test Error ", marker='s', linestyle='--')
plt.xlabel("Training Set Size")
plt.ylabel("Error Rate")    
plt.title(f"num_trees = {num_trees}")
plt.legend()
plt.grid(True)
plt.show()
results[num_trees] = [train_error,test_error]

# %% [markdown]
# num_trees = 50

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
num_trees = 50
train_error = []
test_error = []
train_sizes = np.linspace(0.1, 0.9, 9)

for train_size in train_sizes:
    X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=train_size,random_state=42)
    clf = RandomForestClassifier(n_estimators=num_trees,random_state=42,n_jobs=-1)
    clf.fit(X_train,y_train)

    #train error
    y_train_pred = clf.predict(X_train)
    cur_training_err = 1 - accuracy_score(y_train, y_train_pred)

    # Compute test error
    y_test_pred = clf.predict(X_test)
    cur_test_error = 1 - accuracy_score(y_test, y_test_pred)

    train_error.append(cur_training_err)
    test_error.append(cur_test_error)

plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_error, label="Training Error", marker='o', linestyle='-')
plt.plot(train_sizes, test_error, label="Test Error ", marker='s', linestyle='--')
plt.xlabel("Training Set Size")
plt.ylabel("Error Rate")    
plt.title(f"num_trees = {num_trees}")
plt.legend()
plt.grid(True)
plt.show()
results[num_trees] = [train_error,test_error]

# %% [markdown]
# num_trees = 100

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
num_trees = 100
train_error = []
test_error = []
train_sizes = np.linspace(0.1, 0.9, 9)

for train_size in train_sizes:
    X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=train_size,random_state=42)
    clf = RandomForestClassifier(n_estimators=num_trees,random_state=42,n_jobs=-1)
    clf.fit(X_train,y_train)

    #train error
    y_train_pred = clf.predict(X_train)
    cur_training_err = 1 - accuracy_score(y_train, y_train_pred)

    # Compute test error
    y_test_pred = clf.predict(X_test)
    cur_test_error = 1 - accuracy_score(y_test, y_test_pred)

    train_error.append(cur_training_err)
    test_error.append(cur_test_error)

plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_error, label="Training Error", marker='o', linestyle='-')
plt.plot(train_sizes, test_error, label="Test Error ", marker='s', linestyle='--')
plt.xlabel("Training Set Size")
plt.ylabel("Error Rate")    
plt.title(f"num_trees = {num_trees}")
plt.legend()
plt.grid(True)
plt.show()
results[num_trees] = [train_error,test_error]

# %% [markdown]
# num_trees = 200

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
num_trees = 200
train_error = []
test_error = []
train_sizes = np.linspace(0.1, 0.9, 9)

for train_size in train_sizes:
    X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=train_size,random_state=42)
    clf = RandomForestClassifier(n_estimators=num_trees,random_state=42,n_jobs=-1)
    clf.fit(X_train,y_train)

    #train error
    y_train_pred = clf.predict(X_train)
    cur_training_err = 1 - accuracy_score(y_train, y_train_pred)

    # Compute test error
    y_test_pred = clf.predict(X_test)
    cur_test_error = 1 - accuracy_score(y_test, y_test_pred)

    train_error.append(cur_training_err)
    test_error.append(cur_test_error)

plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_error, label="Training Error", marker='o', linestyle='-')
plt.plot(train_sizes, test_error, label="Test Error ", marker='s', linestyle='--')
plt.xlabel("Training Set Size")
plt.ylabel("Error Rate")    
plt.title(f"num_trees = {num_trees}")
plt.legend()
plt.grid(True)
plt.show()
results[num_trees] = [train_error,test_error]

# %% [markdown]
# num_trees = 500

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
num_trees = 500
train_error = []
test_error = []
train_sizes = np.linspace(0.1, 0.9, 9)

for train_size in train_sizes:
    X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=train_size,random_state=42)
    clf = RandomForestClassifier(n_estimators=num_trees,random_state=42,n_jobs=-1)
    clf.fit(X_train,y_train)

    #train error
    y_train_pred = clf.predict(X_train)
    cur_training_err = 1 - accuracy_score(y_train, y_train_pred)

    # Compute test error
    y_test_pred = clf.predict(X_test)
    cur_test_error = 1 - accuracy_score(y_test, y_test_pred)

    train_error.append(cur_training_err)
    test_error.append(cur_test_error)

plt.figure(figsize=(8,6))
plt.plot(train_sizes, train_error, label="Training Error", marker='o', linestyle='-')
plt.plot(train_sizes, test_error, label="Test Error ", marker='s', linestyle='--')
plt.xlabel("Training Set Size")
plt.ylabel("Error Rate")    
plt.title(f"num_trees = {num_trees}")
plt.legend()
plt.grid(True)
plt.show()
results[num_trees] = [train_error,test_error]

# %%
print(results)
# Out:
# {5: [[0.013043478260869601, 0.013043478260869601, 0.007971014492753614, 0.011413043478260887, 0.009565217391304337, 0.0068840579710145455, 0.008385093167701863, 0.008695652173912993, 0.008212560386473444], [0.1089371980676328, 0.10597826086956519, 0.07763975155279501, 0.06920289855072459, 0.0708695652173913, 0.07010869565217392, 0.07463768115942027, 0.07391304347826089, 0.07826086956521738]], 50: [[0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0009661835748792091], [0.09033816425120778, 0.07826086956521738, 0.06583850931677016, 0.05760869565217386, 0.057826086956521694, 0.0581521739130435, 0.06811594202898552, 0.06304347826086953, 0.05217391304347829]], 100: [[0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791], [0.08550724637681162, 0.07364130434782612, 0.06490683229813665, 0.05869565217391304, 0.057826086956521694, 0.0581521739130435, 0.062318840579710155, 0.06521739130434778, 0.05652173913043479]], 200: [[0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791], [0.08236714975845416, 0.07499999999999996, 0.0661490683229814, 0.05724637681159417, 0.05608695652173912, 0.05326086956521736, 0.06014492753623191, 0.06521739130434778, 0.060869565217391286]], 500: [[0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791], [0.08357487922705309, 0.07391304347826089, 0.0670807453416149, 0.05398550724637685, 0.05652173913043479, 0.05217391304347829, 0.060869565217391286, 0.06304347826086953, 0.060869565217391286]]}

# %%
for k,v in results.items():
    print(f"num trees = {k} : ")
    print(f"training error : {v[0]}")
    print(f"test error : {v[1]}")
    print('----------------')
# Out:
# num trees = 5 :
# training error : [0.013043478260869601, 0.013043478260869601, 0.007971014492753614, 0.011413043478260887, 0.009565217391304337, 0.0068840579710145455, 0.008385093167701863, 0.008695652173912993, 0.008212560386473444]
# test error : [0.1089371980676328, 0.10597826086956519, 0.07763975155279501, 0.06920289855072459, 0.0708695652173913, 0.07010869565217392, 0.07463768115942027, 0.07391304347826089, 0.07826086956521738]
# ----------------
# num trees = 50 :
# training error : [0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0009661835748792091]
# test error : [0.09033816425120778, 0.07826086956521738, 0.06583850931677016, 0.05760869565217386, 0.057826086956521694, 0.0581521739130435, 0.06811594202898552, 0.06304347826086953, 0.05217391304347829]
# ----------------
# num trees = 100 :
# training error : [0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791]
# test error : [0.08550724637681162, 0.07364130434782612, 0.06490683229813665, 0.05869565217391304, 0.057826086956521694, 0.0581521739130435, 0.062318840579710155, 0.06521739130434778, 0.05652173913043479]
# ----------------
# num trees = 200 :
# training error : [0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791]
# test error : [0.08236714975845416, 0.07499999999999996, 0.0661490683229814, 0.05724637681159417, 0.05608695652173912, 0.05326086956521736, 0.06014492753623191, 0.06521739130434778, 0.060869565217391286]
# ----------------
# num trees = 500 :
# training error : [0.0, 0.0, 0.0014492753623188692, 0.0010869565217391797, 0.0008695652173913437, 0.0007246376811593791, 0.0006211180124223725, 0.0005434782608695343, 0.0007246376811593791]
# test error : [0.08357487922705309, 0.07391304347826089, 0.0670807453416149, 0.05398550724637685, 0.05652173913043479, 0.05217391304347829, 0.060869565217391286, 0.06304347826086953, 0.060869565217391286]
# ----------------
